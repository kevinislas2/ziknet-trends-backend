# %%
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
sns.set_style("whitegrid")

# %%
errors = pd.read_csv("Naive/Mexico/Naive_Chiapas_2016-2018.csv", header=0, index_col=0)[1:] #Skip first row

# %%
err = errors["Error"]
ax = sns.violinplot(x=errors["Error"])
